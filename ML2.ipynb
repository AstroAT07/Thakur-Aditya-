# %%
# Python program to find the
# regression line

# Function to calculate b
def calculateB(x, y, n):

    # sum of array x
    sx = sum(x)

    # sum of array y
    sy = sum(y)

    # for sum of product of x and y
    sxsy = 0

    # sum of square of x
    sx2 = 0

    for i in range(n):
        sxsy += x[i] * y[i]
        sx2 += x[i] * x[i]
    b = (n * sxsy - sx * sy)/(n * sx2 - sx * sx)
    return b

# Function to find the
# least regression line
def leastRegLine(X,Y,n):

    # Finding b
    b = calculateB(X, Y, n)
    meanX = int(sum(X)/n)
    meanY = int(sum(Y)/n)

    # Calculating a
    a = meanY - b * meanX

    # Printing regression line
    print("Regression line:")
    print("Y = ", '%.3f'%a, " + ", '%.3f'%b, "*X", sep="")

# Driver code

# Statistical data
X = [95, 85, 80, 70, 60 ]
Y = [90, 80, 70, 65, 60 ]
n = len(X)
leastRegLine(X, Y, n)
# Out:
# Regression line:
# Y = 5.685 + 0.863*X

# %%
import matplotlib.pyplot as plt
import numpy as np

def calculateB(x, y, n):
    sx = sum(x)
    sy = sum(y)
    sxsy = 0
    sx2 = 0
    for i in range(n):
        sxsy += x[i] * y[i]
        sx2 += x[i] * x[i]
    b = (n * sxsy - sx * sy)/(n * sx2 - sx * sx)
    return b

def leastRegLine(X,Y,n):
    # Finding b
    b = calculateB(X, Y, n)
    meanX = sum(X)/n
    meanY = sum(Y)/n

    a = meanY - b * meanX

    print("Regression line:")
    print("Y = {:.3f} + {:.3f}*X".format(a, b))

    # Plotting the regression line
    x_line = np.linspace(min(X), max(X), 100)
    y_line = a + b * x_line
    plt.plot(X, Y, 'o')
    plt.plot(x_line, y_line)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Regression Line')
    plt.grid(True)
    plt.show()

    # Predicting y for a given x
    x_input = float(input("Enter a value for x: "))
    y_predicted = a + b * x_input
    print("Predicted y for x = {:.2f} is {:.2f}".format(x_input, y_predicted))

X = [95, 85, 80, 70, 60 ]
Y = [90, 80, 70, 65, 60 ]
n = len(X)
leastRegLine(X, Y, n)
# Out:
# Regression line:
# Y = 5.685 + 0.863*X

# %%
# prompt: CODE FOR GRADIENT DISTANCE IN ML

import numpy as np

def gradient_distance(X, Y):
    """
    Calculates the gradient distance between two data points.

    Args:
        X: A NumPy array representing the first data point.
        Y: A NumPy array representing the second data point.

    Returns:
        The gradient distance between X and Y.
    """

    if not isinstance(X, np.ndarray) or not isinstance(Y, np.ndarray):
        raise TypeError("X and Y must be NumPy arrays.")

    if X.shape != Y.shape:
        raise ValueError("X and Y must have the same shape.")

    # Calculate the gradient
    gradient = np.gradient(X - Y)

    # Calculate the gradient distance
    gradient_distance = np.linalg.norm(gradient)

    return gradient_distance


# Example usage
X = np.array([1, 2, 3, 4, 5])
Y = np.array([2, 4, 5, 4, 5])
distance = gradient_distance(X, Y)
print("Gradient Distance:", distance)
# Out:
# Gradient Distance: 1.8027756377319946

# %%
# prompt: GIVE GRAAPH OF ABOVE GRADISTIENT DISTANE

import matplotlib.pyplot as plt
import numpy as np

# ... (Existing code for regression line and gradient_distance function)


def gradient_distance(X, Y):
    # ... (Existing code for gradient_distance function)


# Example usage with plotting
X = np.array([1, 2, 3, 4, 5])
Y = np.array([2, 4, 5, 4, 5])

# Calculate gradient distance
distance = gradient_distance(X, Y)
print("Gradient Distance:", distance)

# Generate data points for plotting
x_vals = np.linspace(min(X), max(X), 100)
y_vals = np.interp(x_vals, X, Y) #interpolate Y values for smooth curve

# Create the plot
plt.plot(X, Y, 'o', label='Original Data')  # Plot the original data points
plt.plot(x_vals, y_vals, label='Interpolated Data') # Plot interpolated data

# Add labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Distance Visualization')
plt.legend()  # Display the legend
plt.grid(True)

# Show the plot
plt.show()
# Out:
#   File "<ipython-input-2-ab0ab05cef8d>", line 14
#     X = np.array([1, 2, 3, 4, 5])
#     ^
# IndentationError: expected an indented block after function definition on line 9

# %%
# prompt: GIVE GRAAPH OF ABOVE GRADISTIENT DISTANE

import matplotlib.pyplot as plt
import numpy as np

# ... (Existing code for regression line and gradient_distance function)


def gradient_distance(X, Y):
    """
    Calculates the gradient distance between two data points.

    Args:
        X: A NumPy array representing the first data point.
        Y: A NumPy array representing the second data point.

    Returns:
        The gradient distance between X and Y.
    """
    # The following lines were not indented causing the error
    # Indenting them will fix the issue
    if not isinstance(X, np.ndarray) or not isinstance(Y, np.ndarray):
        raise TypeError("X and Y must be NumPy arrays.")

    if X.shape != Y.shape:
        raise ValueError("X and Y must have the same shape.")

    # Calculate the gradient
    gradient = np.gradient(X - Y)

    # Calculate the gradient distance
    gradient_distance = np.linalg.norm(gradient)

    return gradient_distance


# Example usage with plotting
X = np.array([1, 2, 3, 4, 5])
Y = np.array([2, 4, 5, 4, 5])

# Calculate gradient distance
distance = gradient_distance(X, Y)
print("Gradient Distance:", distance)

# Generate data points for plotting
x_vals = np.linspace(min(X), max(X), 100)
y_vals = np.interp(x_vals, X, Y) #interpolate Y values for smooth curve

# Create the plot
plt.plot(X, Y, 'o', label='Original Data')  # Plot the original data points
plt.plot(x_vals, y_vals, label='Interpolated Data') # Plot interpolated data

# Add labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Distance Visualization')
plt.legend()  # Display the legend
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Gradient Distance: 1.8027756377319946

# %%
# prompt: GIVE THE CODE AND GRAPH OF BATCH AND STOCHASTIC GRADIENT

import matplotlib.pyplot as plt
import numpy as np

# ... (Your existing code for regression line and gradient_distance)


# Batch Gradient Descent
def batch_gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = len(y)
    theta = np.zeros(2)  # Initialize theta (intercept and slope)
    cost_history = []

    for _ in range(iterations):
        h = theta[0] + theta[1] * X  # Hypothesis
        cost = (1 / (2 * m)) * np.sum((h - y) ** 2)  # Cost function
        cost_history.append(cost)

        gradient_theta0 = (1 / m) * np.sum(h - y)
        gradient_theta1 = (1 / m) * np.sum((h - y) * X)

        theta[0] = theta[0] - learning_rate * gradient_theta0
        theta[1] = theta[1] - learning_rate * gradient_theta1
    return theta, cost_history

# Stochastic Gradient Descent
def stochastic_gradient_descent(X, y, learning_rate=0.01, iterations=1000):
    m = len(y)
    theta = np.zeros(2)
    cost_history = []

    for _ in range(iterations):
        for i in range(m):
            h = theta[0] + theta[1] * X[i]
            cost = (1 / 2) * (h - y[i]) ** 2 # Cost for single datapoint
            cost_history.append(cost)

            gradient_theta0 = (h - y[i])
            gradient_theta1 = (h - y[i]) * X[i]

            theta[0] = theta[0] - learning_rate * gradient_theta0
            theta[1] = theta[1] - learning_rate * gradient_theta1
    return theta, cost_history


# Example usage
X = np.array([95, 85, 80, 70, 60])
y = np.array([90, 80, 70, 65, 60])

# Batch Gradient Descent
theta_batch, cost_history_batch = batch_gradient_descent(X, y)

# Stochastic Gradient Descent
theta_stochastic, cost_history_stochastic = stochastic_gradient_descent(X, y)


#Plot the cost history for both methods
plt.plot(cost_history_batch, label='Batch Gradient Descent')
plt.plot(cost_history_stochastic, label='Stochastic Gradient Descent')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Gradient Descent Cost Comparison')
plt.legend()
plt.show()

# Print the results
print("Batch Gradient Descent - Theta:", theta_batch)
print("Stochastic Gradient Descent - Theta:", theta_stochastic)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# <ipython-input-4-3b713228f843>:17: RuntimeWarning: overflow encountered in square
#   cost = (1 / (2 * m)) * np.sum((h - y) ** 2)  # Cost function
# <ipython-input-4-3b713228f843>:24: RuntimeWarning: invalid value encountered in scalar subtract
#   theta[1] = theta[1] - learning_rate * gradient_theta1
# <ipython-input-4-3b713228f843>:36: RuntimeWarning: overflow encountered in scalar power
#   cost = (1 / 2) * (h - y[i]) ** 2 # Cost for single datapoint
# <ipython-input-4-3b713228f843>:40: RuntimeWarning: overflow encountered in scalar multiply
#   gradient_theta1 = (h - y[i]) * X[i]
# <ipython-input-4-3b713228f843>:43: RuntimeWarning: invalid value encountered in scalar subtract
#   theta[1] = theta[1] - learning_rate * gradient_theta1
# Batch Gradient Descent - Theta: [nan nan]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to compute the cost
def cost_function(x):
    return 4 * x**2

# Derivative of the cost function
def gradient(x):
    return 8 * x

# Gradient Descent Implementation
def gradient_descent(starting_point, learning_rate, num_iterations):
    x = starting_point
    history = []

    for _ in range(num_iterations):
        grad = gradient(x)
        x = x - learning_rate * grad
        history.append(cost_function(x))

    return x, history

# Parameters
starting_point = 3  # Initial guess
learning_rate = 0.01
num_iterations = 100

# Run Gradient Descent
min_x, cost_history = gradient_descent(starting_point, learning_rate, num_iterations)

# Output results
print(f'Minimum x: {min_x}')
print(f'Cost at minimum: {cost_function(min_x)}')

# Plotting the cost function
plt.plot(cost_history)
plt.title('Cost Function Over Iterations')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()
# Out:
# Minimum x: 0.0007176356239709939
# Cost at minimum: 2.060003555168951e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

def calculateB(x, y, n):
    sx = sum(x)
    sy = sum(y)
    sxsy = 0
    sx2 = 0
    for i in range(n):
        sxsy += x[i] * y[i]
        sx2 += x[i] * x[i]
    b = (n * sxsy - sx * sy)/(n * sx2 - sx * sx)
    return b

def leastRegLine(X,Y,n):
    # Finding b
    b = calculateB(X, Y, n)
    meanX = sum(X)/n
    meanY = sum(Y)/n

    a = meanY - b * meanX

    print("Regression line:")
    print("Y = {:.3f} + {:.3f}*X".format(a, b))

    # Plotting the regression line
    x_line = np.linspace(min(X), max(X), 100)
    y_line = a + b * x_line
    plt.plot(X, Y, 'o')
    plt.plot(x_line, y_line)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Regression Line')
    plt.grid(False)
    plt.show()

    # Predicting y for a given x
    x_input = float(input("Enter a value for x: "))
    y_predicted = a + b * x_input
    print("Predicted y for x = {:.2f} is {:.2f}".format(x_input, y_predicted))

X = [95, 85, 80, 70, 60 ]
Y = [90, 80, 70, 65, 60 ]
n = len(X)
leastRegLine(X, Y, n)
# Out:
# Regression line:
# Y = 5.685 + 0.863*X
# Enter a value for x: 75
# Predicted y for x = 75.00 is 70.41

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data for linear regression
np.random.seed(42)
X = 2 * np.random.rand(100, 1)  # 100 data points, X values between 0 and 2
y = 4 + 3 * X + np.random.randn(100, 1)  # y = 4 + 3 * X + noise

# Add a bias term (X_0 = 1) to the input matrix
X_b = np.c_[np.ones((100, 1)), X]  # Add the intercept term

# Initialize weights (parameters)
theta = np.random.randn(2, 1)  # Random initialization of the weights (2 parameters: bias and slope)

# Hyperparameters
learning_rate = 0.1
n_epochs = 1000  # Number of iterations (epochs)
m = len(X_b)  # Number of data points

# Stochastic Gradient Descent (SGD)
for epoch in range(n_epochs):
    for i in range(m):
        random_index = np.random.randint(m)  # Select a random sample
        xi = X_b[random_index:random_index+1]  # Select one training example
        yi = y[random_index:random_index+1]  # Corresponding target value

        # Compute the prediction
        prediction = xi.dot(theta)

        # Compute the error (gradient)
        error = prediction - yi

        # Update the parameters (weights)
        gradient = xi.T.dot(error)  # Compute the gradient
        theta -= learning_rate * gradient  # Update the weights

    # Print the cost function value every 100 epochs (optional)
    if epoch % 100 == 0:
        cost = np.sum((X_b.dot(theta) - y) ** 2) / (2 * m)  # Mean Squared Error cost function
        print(f"Epoch {epoch}, Cost: {cost}")

# Final parameters after training
print("Final parameters (theta):", theta)

# Plotting the results
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, X_b.dot(theta), color='red', label='SGD Linear Regression Model')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Epoch 0, Cost: 0.4438768101905608
# Epoch 100, Cost: 0.41825923852681623
# Epoch 200, Cost: 0.41038308748171753
# Epoch 300, Cost: 0.6001118608962089
# Epoch 400, Cost: 0.4331718184069414
# Epoch 500, Cost: 0.45374497488287846
# Epoch 600, Cost: 0.4263896125380277
# Epoch 700, Cost: 0.47383384050706523
# Epoch 800, Cost: 0.4462145844753125
# Epoch 900, Cost: 0.7910754732627016
# Final parameters (theta): [[3.98009213]
#  [2.96688391]]
